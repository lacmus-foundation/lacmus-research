# %%
import os

import numpy as np
import pandas as pd
from PIL import Image, ImageDraw


import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler

import torchvision
from torchvision import datasets, models, transforms
from torchvision.models.detection.retinanet import RetinaNet
from torchvision.models.detection.faster_rcnn import FasterRCNN
import  torchvision.transforms.functional as F

from functions import *
from functions_torch import *

# %%
params = {}
params['target_size']=(800,1333)
params['batch_size'] = 4
params['lr'] = 0.005

# %%
class SDDDataSET(torch.utils.data.Dataset):
    def __init__(self, typeOfDS, transforms=None):
        self.typeOfDS = typeOfDS
        self.labels = pd.read_csv('/app/host/lacmus/dataset/sdd-lacmus-version/%s_annotations_pedestrian.csv'%typeOfDS, header = None, 
            names = ['image','x0','y0','x1','y1','class'])
        self.transforms = transforms
    
    def __len__(self):
        return self.labels.image.nunique()

    def __getitem__(self, idx):
        # load images ad masks
        img_name = self.labels.image.unique()[idx]
        img_labels = self.labels [self.labels.image == img_name]
        img = Image.open('/app/host/lacmus/dataset/sdd-lacmus-version/'+img_name).convert("RGB") #convert from tutorial, do we need it?

        # get bounding box coordinates 
        num_objs = img_labels.shape[0]
        boxes = []
        for l in img_labels.iterrows():
            boxes.append([l[1]['x0'], l[1]['y0'], l[1]['x1'], l[1]['y1']])


        target = {}
        target["boxes"] = torch.as_tensor(boxes, dtype=torch.float32)         # there is only one class
        target["labels"] = labels = torch.ones((num_objs,), dtype=torch.int64)

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

# %%
# Uncomment to test dataset implementation
# im_idx = 10

# dataset = SDDDataSET('test',get_transform(train=True)) 
# (image,target) = dataset[im_idx] 
# im = F.to_pil_image(image)
# draw = ImageDraw.Draw(im)

# for bb in target['boxes']:
#     draw.line([(bb[0], bb[1]), (bb[0], bb[3]), (bb[2], bb[3]),
#                (bb[2], bb[1]), (bb[0], bb[1])], width=4, fill=(255, 0, 0))

# im.show()

# %%
dataset_train = SDDDataSET('train', get_transform(train=True,target_size=params['target_size']))
dataset_val = SDDDataSET('val', get_transform(train=False,target_size=params['target_size']))

# split the dataset in train and test set
torch.manual_seed(1)

# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
    dataset_train, batch_size=params['batch_size'], shuffle=True, num_workers=4
     ,collate_fn=collate_fn
)

data_loader_val = torch.utils.data.DataLoader(
    dataset_val, batch_size=1, shuffle=False, num_workers=4
     ,collate_fn=collate_fn
)

# %%
# # load an instance segmentation model pre-trained on COCO    
# model = torchvision.models.detection.retinanet_resnet50_fpn(pretrained=False, num_classes=2, pretrained_backbone=True,
#                                                             min_size=params['target_size'][0], max_size = params['target_size'][1] )

# %%
# load an instance segmentation model pre-trained on COCO    
model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=False, num_classes=2, pretrained_backbone=True,
                                                            min_size=params['target_size'][0], max_size = params['target_size'][1] )

# %%
# the computation device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=params['lr'], momentum=0.9, weight_decay=0.0005) #lr 0.001 -> 0.005
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=3,
                                               gamma=0.1)

# %%
for epoch in range(10):

    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=250)
    print ("Train done, evaluating.")
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    inference_res = evaluate(model,data_loader_val)
    print('Inference done, computing mAp : ')
    print(evaluate_res(inference_res, iou_threshold = 0.5, score_threshold = 0.05))    
    print(evaluate_res(inference_res, iou_threshold = 0.6, score_threshold = 0.05))
    print('Epoch Done')
    torch.save(model.state_dict(), '/app/host/lacmus/weights/resnet50_FRCNN_SDD_epoch_%i.pth'%epoch)
# Out:
# Epoch: [0]  [  0/639]  eta: 0:27:17  lr: 0.000013  loss: 1.4677 (1.4677)  loss_classifier: 0.7104 (0.7104)  loss_box_reg: 0.0046 (0.0046)  loss_objectness: 0.6910 (0.6910)  loss_rpn_box_reg: 0.0618 (0.0618)  time: 2.5625  data: 1.2208  max mem: 4917
# Epoch: [0]  [250/639]  eta: 0:06:16  lr: 0.001970  loss: 0.9690 (0.8856)  loss_classifier: 0.3126 (0.2825)  loss_box_reg: 0.4919 (0.2481)  loss_objectness: 0.1027 (0.2970)  loss_rpn_box_reg: 0.0497 (0.0581)  time: 0.9793  data: 0.0168  max mem: 5185
# Epoch: [0]  [500/639]  eta: 0:02:15  lr: 0.003927  loss: 0.9112 (0.9261)  loss_classifier: 0.2973 (0.2998)  loss_box_reg: 0.5188 (0.3820)  loss_objectness: 0.0601 (0.1925)  loss_rpn_box_reg: 0.0312 (0.0517)  time: 0.9794  data: 0.0183  max mem: 5185
# Epoch: [0]  [638/639]  eta: 0:00:00  lr: 0.005000  loss: 0.9726 (0.9412)  loss_classifier: 0.3180 (0.3053)  loss_box_reg: 0.5437 (0.4182)  loss_objectness: 0.0649 (0.1664)  loss_rpn_box_reg: 0.0412 (0.0513)  time: 0.9769  data: 0.0175  max mem: 5185
# Epoch: [0] Total time: 0:10:24 (0.9781 s / it)
# Train done, evaluating.
# Inference done, computing mAp :
# 0.28019706551334106
# 0.10784223049820224
# Epoch Done
# Epoch: [1]  [  0/639]  eta: 0:18:52  lr: 0.005000  loss: 1.2296 (1.2296)  loss_classifier: 0.4009 (0.4009)  loss_box_reg: 0.6987 (0.6987)  loss_objectness: 0.0820 (0.0820)  loss_rpn_box_reg: 0.0480 (0.0480)  time: 1.7716  data: 0.8198  max mem: 5185
# Epoch: [1]  [250/639]  eta: 0:06:22  lr: 0.005000  loss: 0.8958 (0.9487)  loss_classifier: 0.2922 (0.3061)  loss_box_reg: 0.5362 (0.5389)  loss_objectness: 0.0501 (0.0587)  loss_rpn_box_reg: 0.0390 (0.0450)  time: 0.9839  data: 0.0185  max mem: 5185
# Epoch: [1]  [500/639]  eta: 0:02:16  lr: 0.005000  loss: 0.9155 (0.9469)  loss_classifier: 0.3063 (0.3051)  loss_box_reg: 0.5087 (0.5420)  loss_objectness: 0.0509 (0.0567)  loss_rpn_box_reg: 0.0291 (0.0432)  time: 0.9814  data: 0.0199  max mem: 5185
# Epoch: [1]  [638/639]  eta: 0:00:00  lr: 0.005000  loss: 0.9090 (0.9407)  loss_classifier: 0.2928 (0.3011)  loss_box_reg: 0.4968 (0.5417)  loss_objectness: 0.0434 (0.0553)  loss_rpn_box_reg: 0.0400 (0.0426)  time: 0.9763  data: 0.0174  max mem: 5185
# Epoch: [1] Total time: 0:10:29 (0.9844 s / it)
# Train done, evaluating.
# Inference done, computing mAp :
# 0.34683263425699645
# 0.13557448084677212
# Epoch Done
# Epoch: [2]  [  0/639]  eta: 0:22:39  lr: 0.005000  loss: 0.7532 (0.7532)  loss_classifier: 0.2443 (0.2443)  loss_box_reg: 0.4446 (0.4446)  loss_objectness: 0.0429 (0.0429)  loss_rpn_box_reg: 0.0214 (0.0214)  time: 2.1275  data: 1.1687  max mem: 5185
# Epoch: [2]  [250/639]  eta: 0:06:22  lr: 0.005000  loss: 0.9164 (0.9051)  loss_classifier: 0.2839 (0.2820)  loss_box_reg: 0.5533 (0.5424)  loss_objectness: 0.0345 (0.0431)  loss_rpn_box_reg: 0.0350 (0.0377)  time: 0.9832  data: 0.0183  max mem: 5185
# Epoch: [2]  [500/639]  eta: 0:02:16  lr: 0.005000  loss: 0.8563 (0.8898)  loss_classifier: 0.2605 (0.2776)  loss_box_reg: 0.4914 (0.5319)  loss_objectness: 0.0309 (0.0433)  loss_rpn_box_reg: 0.0312 (0.0371)  time: 0.9820  data: 0.0198  max mem: 5185
# Epoch: [2]  [638/639]  eta: 0:00:00  lr: 0.005000  loss: 0.8869 (0.8913)  loss_classifier: 0.2843 (0.2782)  loss_box_reg: 0.5215 (0.5328)  loss_objectness: 0.0386 (0.0432)  loss_rpn_box_reg: 0.0293 (0.0371)  time: 0.9785  data: 0.0186  max mem: 5185
# Epoch: [2] Total time: 0:10:29 (0.9853 s / it)
# Train done, evaluating.
# Inference done, computing mAp :
# 0.4147583737847915
# 0.1874253176938546
# Epoch Done
# Epoch: [3]  [  0/639]  eta: 0:22:50  lr: 0.000500  loss: 1.0537 (1.0537)  loss_classifier: 0.3143 (0.3143)  loss_box_reg: 0.6768 (0.6768)  loss_objectness: 0.0205 (0.0205)  loss_rpn_box_reg: 0.0421 (0.0421)  time: 2.1442  data: 1.1847  max mem: 5185
# Epoch: [3]  [250/639]  eta: 0:06:23  lr: 0.000500  loss: 0.8263 (0.8356)  loss_classifier: 0.2507 (0.2557)  loss_box_reg: 0.5067 (0.5155)  loss_objectness: 0.0331 (0.0331)  loss_rpn_box_reg: 0.0293 (0.0313)  time: 0.9830  data: 0.0180  max mem: 5185
# Epoch: [3]  [500/639]  eta: 0:02:16  lr: 0.000500  loss: 0.7554 (0.8358)  loss_classifier: 0.2386 (0.2561)  loss_box_reg: 0.4574 (0.5148)  loss_objectness: 0.0251 (0.0328)  loss_rpn_box_reg: 0.0259 (0.0321)  time: 0.9823  data: 0.0202  max mem: 5185
# Epoch: [3]  [638/639]  eta: 0:00:00  lr: 0.000500  loss: 0.8099 (0.8354)  loss_classifier: 0.2440 (0.2559)  loss_box_reg: 0.5256 (0.5152)  loss_objectness: 0.0238 (0.0324)  loss_rpn_box_reg: 0.0267 (0.0319)  time: 0.9781  data: 0.0167  max mem: 5185
# Epoch: [3] Total time: 0:10:30 (0.9864 s / it)
# Train done, evaluating.
# Inference done, computing mAp :
# 0.4384376423051358
# 0.20449068813702814
# Epoch Done
# Epoch: [4]  [  0/639]  eta: 0:21:22  lr: 0.000500  loss: 0.9690 (0.9690)  loss_classifier: 0.2750 (0.2750)  loss_box_reg: 0.6107 (0.6107)  loss_objectness: 0.0258 (0.0258)  loss_rpn_box_reg: 0.0574 (0.0574)  time: 2.0066  data: 1.0453  max mem: 5185
# Epoch: [4]  [250/639]  eta: 0:06:23  lr: 0.000500  loss: 0.8472 (0.8203)  loss_classifier: 0.2639 (0.2511)  loss_box_reg: 0.5334 (0.5090)  loss_objectness: 0.0381 (0.0301)  loss_rpn_box_reg: 0.0346 (0.0301)  time: 0.9831  data: 0.0185  max mem: 5185
# Epoch: [4]  [500/639]  eta: 0:02:16  lr: 0.000500  loss: 0.7899 (0.8121)  loss_classifier: 0.2338 (0.2475)  loss_box_reg: 0.4915 (0.5043)  loss_objectness: 0.0240 (0.0298)  loss_rpn_box_reg: 0.0257 (0.0305)  time: 0.9783  data: 0.0182  max mem: 5185
# Epoch: [4]  [638/639]  eta: 0:00:00  lr: 0.000500  loss: 0.8183 (0.8150)  loss_classifier: 0.2460 (0.2482)  loss_box_reg: 0.5062 (0.5064)  loss_objectness: 0.0305 (0.0297)  loss_rpn_box_reg: 0.0249 (0.0308)  time: 0.9770  data: 0.0170  max mem: 5185
# Epoch: [4] Total time: 0:10:29 (0.9853 s / it)
# Train done, evaluating.
# Inference done, computing mAp :
# 0.45063486930767416
# 0.2135845932994572
# Epoch Done
# Epoch: [5]  [  0/639]  eta: 0:23:03  lr: 0.000500  loss: 0.8519 (0.8519)  loss_classifier: 0.2745 (0.2745)  loss_box_reg: 0.5155 (0.5155)  loss_objectness: 0.0390 (0.0390)  loss_rpn_box_reg: 0.0228 (0.0228)  time: 2.1644  data: 1.1973  max mem: 5185
# Epoch: [5]  [250/639]  eta: 0:06:23  lr: 0.000500  loss: 0.7795 (0.7980)  loss_classifier: 0.2406 (0.2425)  loss_box_reg: 0.4943 (0.4979)  loss_objectness: 0.0278 (0.0284)  loss_rpn_box_reg: 0.0250 (0.0291)  time: 0.9810  data: 0.0180  max mem: 5185
# Epoch: [5]  [500/639]  eta: 0:02:16  lr: 0.000500  loss: 0.8134 (0.8010)  loss_classifier: 0.2561 (0.2432)  loss_box_reg: 0.4845 (0.4984)  loss_objectness: 0.0294 (0.0286)  loss_rpn_box_reg: 0.0316 (0.0309)  time: 0.9795  data: 0.0168  max mem: 5185
# Epoch: [5]  [638/639]  eta: 0:00:00  lr: 0.000500  loss: 0.7351 (0.8008)  loss_classifier: 0.2262 (0.2429)  loss_box_reg: 0.4660 (0.4990)  loss_objectness: 0.0243 (0.0283)  loss_rpn_box_reg: 0.0250 (0.0305)  time: 0.9786  data: 0.0180  max mem: 5185
# Epoch: [5] Total time: 0:10:30 (0.9860 s / it)
# Train done, evaluating.
# Inference done, computing mAp :
# 0.43797332935936106
# 0.2141546604412808
# Epoch Done
# Epoch: [6]  [  0/639]  eta: 0:24:19  lr: 0.000050  loss: 0.5882 (0.5882)  loss_classifier: 0.1681 (0.1681)  loss_box_reg: 0.3636 (0.3636)  loss_objectness: 0.0168 (0.0168)  loss_rpn_box_reg: 0.0396 (0.0396)  time: 2.2835  data: 1.3281  max mem: 5185
# Epoch: [6]  [250/639]  eta: 0:06:23  lr: 0.000050  loss: 0.8330 (0.7888)  loss_classifier: 0.2431 (0.2384)  loss_box_reg: 0.5327 (0.4923)  loss_objectness: 0.0234 (0.0275)  loss_rpn_box_reg: 0.0284 (0.0307)  time: 0.9832  data: 0.0195  max mem: 5185
# Epoch: [6]  [500/639]  eta: 0:02:16  lr: 0.000050  loss: 0.8285 (0.7900)  loss_classifier: 0.2493 (0.2391)  loss_box_reg: 0.5253 (0.4945)  loss_objectness: 0.0249 (0.0266)  loss_rpn_box_reg: 0.0242 (0.0298)  time: 0.9800  data: 0.0172  max mem: 5185
# Epoch: [6]  [638/639]  eta: 0:00:00  lr: 0.000050  loss: 0.7976 (0.7867)  loss_classifier: 0.2415 (0.2381)  loss_box_reg: 0.4830 (0.4924)  loss_objectness: 0.0254 (0.0265)  loss_rpn_box_reg: 0.0280 (0.0297)  time: 0.9711  data: 0.0143  max mem: 5185
# Epoch: [6] Total time: 0:10:29 (0.9854 s / it)
# Train done, evaluating.
# Inference done, computing mAp :
# 0.43700977439761834
# 0.21639985498098846
# Epoch Done
# Epoch: [7]  [  0/639]  eta: 0:18:54  lr: 0.000050  loss: 0.8163 (0.8163)  loss_classifier: 0.2440 (0.2440)  loss_box_reg: 0.5286 (0.5286)  loss_objectness: 0.0181 (0.0181)  loss_rpn_box_reg: 0.0256 (0.0256)  time: 1.7755  data: 0.8215  max mem: 5185
# Epoch: [7]  [250/639]  eta: 0:06:21  lr: 0.000050  loss: 0.7930 (0.7719)  loss_classifier: 0.2418 (0.2346)  loss_box_reg: 0.5058 (0.4824)  loss_objectness: 0.0247 (0.0251)  loss_rpn_box_reg: 0.0298 (0.0298)  time: 0.9812  data: 0.0185  max mem: 5185
# Epoch: [7]  [500/639]  eta: 0:02:15  lr: 0.000050  loss: 0.8054 (0.7816)  loss_classifier: 0.2322 (0.2371)  loss_box_reg: 0.5177 (0.4891)  loss_objectness: 0.0198 (0.0260)  loss_rpn_box_reg: 0.0290 (0.0294)  time: 0.9797  data: 0.0175  max mem: 5185
# Epoch: [7]  [638/639]  eta: 0:00:00  lr: 0.000050  loss: 0.7582 (0.7827)  loss_classifier: 0.2322 (0.2375)  loss_box_reg: 0.4920 (0.4895)  loss_objectness: 0.0249 (0.0262)  loss_rpn_box_reg: 0.0229 (0.0296)  time: 0.9697  data: 0.0141  max mem: 5185
# Epoch: [7] Total time: 0:10:26 (0.9798 s / it)
# Train done, evaluating.
# Inference done, computing mAp :
# 0.43666941161678274
# 0.21331997562048935
# Epoch Done
# Epoch: [8]  [  0/639]  eta: 0:18:52  lr: 0.000050  loss: 0.8202 (0.8202)  loss_classifier: 0.2685 (0.2685)  loss_box_reg: 0.4879 (0.4879)  loss_objectness: 0.0303 (0.0303)  loss_rpn_box_reg: 0.0335 (0.0335)  time: 1.7717  data: 0.7863  max mem: 5185
# Epoch: [8]  [250/639]  eta: 0:06:19  lr: 0.000050  loss: 0.8089 (0.7726)  loss_classifier: 0.2490 (0.2337)  loss_box_reg: 0.5115 (0.4856)  loss_objectness: 0.0227 (0.0254)  loss_rpn_box_reg: 0.0279 (0.0280)  time: 0.9708  data: 0.0141  max mem: 5185
# Epoch: [8]  [500/639]  eta: 0:02:15  lr: 0.000050  loss: 0.8188 (0.7803)  loss_classifier: 0.2596 (0.2362)  loss_box_reg: 0.4950 (0.4883)  loss_objectness: 0.0273 (0.0266)  loss_rpn_box_reg: 0.0319 (0.0291)  time: 0.9704  data: 0.0138  max mem: 5185
# Epoch: [8]  [638/639]  eta: 0:00:00  lr: 0.000050  loss: 0.7871 (0.7822)  loss_classifier: 0.2425 (0.2371)  loss_box_reg: 0.4879 (0.4890)  loss_objectness: 0.0167 (0.0266)  loss_rpn_box_reg: 0.0243 (0.0295)  time: 0.9729  data: 0.0159  max mem: 5185
# Epoch: [8] Total time: 0:10:23 (0.9760 s / it)
# Train done, evaluating.
# Inference done, computing mAp :
# 0.4374107073316398
# 0.2151567111475402
# Epoch Done
# Epoch: [9]  [  0/639]  eta: 0:20:35  lr: 0.000005  loss: 0.9776 (0.9776)  loss_classifier: 0.2820 (0.2820)  loss_box_reg: 0.6258 (0.6258)  loss_objectness: 0.0264 (0.0264)  loss_rpn_box_reg: 0.0434 (0.0434)  time: 1.9333  data: 0.9311  max mem: 5185
# Epoch: [9]  [250/639]  eta: 0:06:23  lr: 0.000005  loss: 0.7424 (0.7824)  loss_classifier: 0.2265 (0.2372)  loss_box_reg: 0.4840 (0.4895)  loss_objectness: 0.0198 (0.0262)  loss_rpn_box_reg: 0.0244 (0.0295)  time: 0.9900  data: 0.0227  max mem: 5185
# Epoch: [9]  [500/639]  eta: 0:02:17  lr: 0.000005  loss: 0.7371 (0.7834)  loss_classifier: 0.2160 (0.2372)  loss_box_reg: 0.4589 (0.4903)  loss_objectness: 0.0248 (0.0258)  loss_rpn_box_reg: 0.0307 (0.0301)  time: 0.9871  data: 0.0198  max mem: 5185
# Epoch: [9]  [638/639]  eta: 0:00:00  lr: 0.000005  loss: 0.7931 (0.7805)  loss_classifier: 0.2316 (0.2363)  loss_box_reg: 0.5179 (0.4889)  loss_objectness: 0.0215 (0.0258)  loss_rpn_box_reg: 0.0277 (0.0295)  time: 0.9868  data: 0.0221  max mem: 5185
# Epoch: [9] Total time: 0:10:32 (0.9897 s / it)
# Train done, evaluating.
# Inference done, computing mAp :
# 0.4403135808490371
# 0.2153521313769284
# Epoch Done

# %%
# # uncomment to test evaluation model and show detections

# cpu_device = torch.device("cpu")
# model.eval()
# for images, targets in data_loader:
#     g_images = list(img.to(device) for img in images)

#     if torch.cuda.is_available():
#         torch.cuda.synchronize()
#     outputs = model(g_images)

#     outputs = [{k: v.to(cpu_device) for k, v in t.items()} for t in outputs]
#     res = targets, outputs
#     break

# im = F.to_pil_image(images[0])
# targets
# # im = to_pil_image(dataset[10][0])
# draw = ImageDraw.Draw(im)

# for bb in outputs[0]['boxes'][:10]:
#     draw.line([(bb[0], bb[1]), (bb[0], bb[3]), (bb[2], bb[3]),
#                (bb[2], bb[1]), (bb[0], bb[1])], width=4, fill=(255, 0, 0))

# for bb in targets[0]['boxes'][:10]:
#     draw.line([(bb[0], bb[1]), (bb[0], bb[3]), (bb[2], bb[3]),
#                (bb[2], bb[1]), (bb[0], bb[1])], width=4, fill=(0,255, 0))
# im.show()

# # # This suggests test set is far from perfect
